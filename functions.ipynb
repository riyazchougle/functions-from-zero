# %% [markdown]
# <a href="https://colab.research.google.com/github/riyazchougle/functions-from-zero/blob/main/functions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
